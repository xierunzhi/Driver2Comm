# %%
import Driver2Comm as dc
import pandas as pd

# %%
patient_metadata = pd.read_csv('F:/Driver2Comm/Experiment/data/21_brca/brca_annotation.csv')
patient_metadata
# Out:
#      patient driver
# 0   CID3921A   HER2
# 1   CID3921B   HER2
# 2   CID3921C   HER2
# 3   CID3921D   HER2
# 4   CID3921E   HER2
# ..       ...    ...
# 56  CID4535A     ER
# 57  CID4535B     ER
# 58  CID4535C     ER
# 59  CID4535D     ER
# 60  CID4535E     ER
#
# [61 rows x 2 columns]

# %%
a = dc.Driver2Comm(
    minsup=3,
    inputPATH = 'D:/Driver2Comm/data/cytotalk_input/',
    patient_metadata = patient_metadata,
    outputPATH = 'D:/Driver2Comm/data',
    cancer_type = 'Brca',
    visualize = True,
)

# %%
a.run()
# Out:
# t # 0
# v 0 Arpc5__Macrophages
# v 1 Spint2__Macrophages
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 1
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 2
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 3
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# v 3 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 4
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# v 3 Hla-drb5__Macrophages
# v 4 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
# e 3 4 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 5
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 6
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# v 3 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 2 3 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 7
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921E']
#
# -----------------
#
# t # 8
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-dra__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 9
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-dra__Macrophages
# v 4 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
# e 1 4 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 10
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-dra__Macrophages
# v 4 Hla-drb5__Macrophages
# v 5 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
# e 1 4 1
# e 4 5 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 11
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 12
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-drb5__Macrophages
# v 4 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
# e 3 4 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 13
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa1__Macrophages
# v 3 Hla-dqa2__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 14
# v 0 Hla-dpb1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa2__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 15
# v 0 C3ar1__Macrophages
# v 1 Lamp1__Macrophages
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 16
# v 0 C3ar1__Macrophages
# v 1 Lamp1__Macrophages
# v 2 C4a__Tumor
# e 0 1 0
# e 0 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 17
# v 0 C3ar1__Macrophages
# v 1 C4a__Tumor
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 18
# v 0 Hspa8__Cd8+Tcells
# v 1 Stat4__Cd8+Tcells
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 19
# v 0 Hspa1a__Cd8+Tcells
# v 1 Hspa1b__Cd8+Tcells
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 20
# v 0 Dnajb1__Cd8+Tcells
# v 1 Hspa8__Cd8+Tcells
# e 0 1 0
#
# Support: 3
# where: ['CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 21
# v 0 Ifng__Cd8+Tcells
# v 1 Ifngr1__Macrophages
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 22
# v 0 Cadm1__Macrophages
# v 1 Crtam__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921B', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 23
# v 0 Xcl1__Cd8+Tcells
# v 1 Xcl2__Cd8+Tcells
# e 0 1 0
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 24
# v 0 Ccl5__Cd8+Tcells
# v 1 Sdc4__Tumor
# e 0 1 1
#
# Support: 4
# where: ['CID3921E', 'CID3921B', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 25
# v 0 Ccl5__Cd8+Tcells
# v 1 Sdc1__Tumor
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 26
# v 0 Ccl5__Cd8+Tcells
# v 1 Sdc1__Tumor
# v 2 Sdc4__Tumor
# e 0 1 1
# e 0 2 1
#
# Support: 4
# where: ['CID3921E', 'CID3921B', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 27
# v 0 Dnaja1__Cd8+Tcells
# v 1 Hsph1__Cd8+Tcells
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921A']
#
# -----------------
#
# t # 28
# v 0 Tff1__Tumor
# v 1 Tff3__Tumor
# e 0 1 0
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 29
# v 0 Azgp1__Tumor
# v 1 Pip__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 30
# v 0 Plxnb2__Tumor
# v 1 Sema4d__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 31
# v 0 Cxcl13__Tumor
# v 1 Cxcr3__Cd8+Tcells
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 32
# v 0 Plxnb1__Tumor
# v 1 Sema4d__Cd8+Tcells
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 33
# v 0 Plxnb1__Tumor
# v 1 Sema4d__Cd8+Tcells
# v 2 Plxnb2__Tumor
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 34
# v 0 Akr7a3__Tumor
# v 1 Cox16__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 35
# v 0 Celsr1__Tumor
# v 1 Psap__Macrophages
# e 0 1 1
#
# Support: 5
# where: ['CID3921B', 'CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 36
# v 0 Nbeal1__Tumor
# v 1 Rpl12__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 37
# v 0 Mt-co2__Tumor
# v 1 Mt-nd4__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921A']
#
# -----------------
#
# t # 38
# v 0 Atf3__Tumor
# v 1 Hspb1__Tumor
# e 0 1 0
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921E', 'CID3921A']
#
# -----------------
#
# t # 39
# v 0 Erbb2__Tumor
# v 1 Sema4d__Cd8+Tcells
# e 0 1 1
#
# Support: 4
# where: ['CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 40
# v 0 Erbb2__Tumor
# v 1 Sema4d__Cd8+Tcells
# v 2 Plxnb1__Tumor
# e 0 1 1
# e 1 2 1
#
# Support: 4
# where: ['CID3921D', 'CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 41
# v 0 Erbb2__Tumor
# v 1 Sema4d__Cd8+Tcells
# v 2 Plxnb1__Tumor
# v 3 Plxnb2__Tumor
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 42
# v 0 Erbb2__Tumor
# v 1 Sema4d__Cd8+Tcells
# v 2 Plxnb2__Tumor
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921E', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 43
# v 0 Apoc1__Macrophages
# v 1 Lgals1__Macrophages
# e 0 1 0
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921A']
#
# -----------------
#
# t # 44
# v 0 Hla-b__Cd8+Tcells
# v 1 Hla-c__Cd8+Tcells
# e 0 1 0
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921E']
#
# -----------------
#
# t # 45
# v 0 Hla-drb1__Macrophages
# v 1 Hla-drb5__Macrophages
# e 0 1 0
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921E']
#
# -----------------
#
# t # 46
# v 0 Hla-drb1__Macrophages
# v 1 Hla-drb5__Macrophages
# v 2 Lag3__Cd8+Tcells
# e 0 1 0
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 47
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# e 0 1 1
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921E']
#
# -----------------
#
# t # 48
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 49
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# v 3 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 50
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dra__Macrophages
# v 3 Hla-drb5__Macrophages
# v 4 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 1 3 1
# e 3 4 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 51
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 52
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# v 3 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 2 3 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 53
# v 0 Hla-dqa1__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-dqa2__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 54
# v 0 Apoe__Macrophages
# v 1 Scarb1__Tumor
# e 0 1 1
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 55
# v 0 Apoe__Macrophages
# v 1 Scarb1__Tumor
# v 2 Ptdss1__Cd8+Tcells
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 56
# v 0 Hla-drb5__Macrophages
# v 1 Lag3__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 57
# v 0 Hla-dra__Macrophages
# v 1 Lag3__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 58
# v 0 Hla-dra__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 59
# v 0 Hla-dra__Macrophages
# v 1 Lag3__Cd8+Tcells
# v 2 Hla-drb5__Macrophages
# v 3 Hla-drb1__Macrophages
# e 0 1 1
# e 1 2 1
# e 2 3 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 60
# v 0 Cxcl16__Macrophages
# v 1 Cxcr6__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 61
# v 0 Ptdss1__Cd8+Tcells
# v 1 Scarb1__Tumor
# e 0 1 1
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 62
# v 0 Mt-co3__Tumor
# v 1 Mt-nd4__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 63
# v 0 Itgb6__Tumor
# v 1 Tgfb1__Cd8+Tcells
# e 0 1 1
#
# Support: 4
# where: ['CID3921D', 'CID3921B', 'CID3921C', 'CID3921E']
#
# -----------------
#
# t # 64
# v 0 Itgb6__Tumor
# v 1 Tgfb1__Cd8+Tcells
# v 2 Itgb8__Tumor
# e 0 1 1
# e 1 2 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 65
# v 0 Itgb8__Tumor
# v 1 Tgfb1__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 66
# v 0 Epcam__Tumor
# v 1 Tmco1__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921E']
#
# -----------------
#
# t # 67
# v 0 Rps4x__Tumor
# v 1 Rps8__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921B', 'CID3921E']
#
# -----------------
#
# t # 68
# v 0 Atf3__Tumor
# v 1 Btg2__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 69
# v 0 Ccdc74a__Tumor
# v 1 Ccdc74b__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921E', 'CID3921B', 'CID3921C']
#
# -----------------
#
# t # 70
# v 0 Gzmk__Cd8+Tcells
# v 1 Il7r__Cd8+Tcells
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 71
# v 0 Capzb__Macrophages
# v 1 Fcgr1a__Macrophages
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 72
# v 0 Hla-dqa2__Macrophages
# v 1 Lag3__Cd8+Tcells
# e 0 1 1
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 73
# v 0 Mt-atp6__Tumor
# v 1 Mt-atp8__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# t # 74
# v 0 Lage3__Tumor
# v 1 Polr2i__Tumor
# e 0 1 0
#
# Support: 3
# where: ['CID3921D', 'CID3921E', 'CID3921C']
#
# -----------------
#
# Number of Frequent Pattern passed the test: 0
# Number of Frequent Pattern passed the test: 75
# Number of Frequent Pattern passed the test: 0
